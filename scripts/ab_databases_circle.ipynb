# %%
import matplotlib.pyplot as plt


group_names_1 = ['Structure data', 'Sequence data', 'Synthetic structure data', 'Developability']
group_size_1 = [5976, 4000000000, 1000000000, 0]


group_names_2 = ['Structures with at least one paired VH/VL', '', 'Antibodies, against different targets', '']
group_size_2 = [5976, 4000000000, 1000000000]

fig, ax = plt.subplots(dpi=400)
#ax = ax.flatten(dpi=400)
ax.axis('equal')


radius = 3
size = 0.3

blues, reds, greens = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]
ab20b, tab20c = [plt.cm.tab20b, plt.cm.tab20c]

nested_pie_1, _ = ax.pie(group_size_1, radius=radius-0*size, #labels=group_names_1, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[blues(0.8), reds(0.8), '#62116D', 'k'])

#nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
#                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
#                         colors=[blues(0.5), reds(0.2), reds(0.4), 'w'])

#nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
#                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
#                         colors=['w', 'w', 'w', 'w'])


    
#plt.legend(frameon=False)
plt.margins(0,0)
#plt.show()

# %%
group_names_1 = ['developability']
group_size_1 = [49]


group_names_2 = ['high-level expression', 'high solubility', 'covalent integrity', 'conformational stability', 'colloidal stability', 'low polyspecificity', 'low immunogenicity']
group_size_2 = [7, 7, 7, 7, 7, 7, 7]

fig, ax = plt.subplots(dpi=400)
#ax = ax.flatten(dpi=400)
ax.axis('equal')


radius = 2
size = 0.3

blues, reds, greys = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greys]
ab20b, tab20c = [plt.cm.tab20b, plt.cm.tab20c]

nested_pie_1, _ = ax.pie(group_size_1, radius=radius-0*size, #labels=group_names_1, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[greys(0.9)])

#nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
#                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
#                         colors=[blues(0.5), reds(0.2), reds(0.4), 'w'])

nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[greys(0.8), greys(0.2), greys(0.3), greys(0.4), greys(0.5), greys(0.6), greys(0.7)])


    
#plt.legend(frameon=False)
plt.margins(0,0)
#plt.show()

# %%
group_names_1 = ['Structure', 'Sequence']
group_size_1 = [5976, 618371034]


group_names_2 = ['Structures with at least one paired VH/VL', '', 'Antibodies, against different targets']
group_size_2 = [5976, 562544071, 55826963]

fig, ax = plt.subplots(dpi=400)
#ax = ax.flatten(dpi=400)
ax.axis('equal')


radius = 3
size = 0.3

blues, reds, greens = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]
ab20b, tab20c = [plt.cm.tab20b, plt.cm.tab20c]

nested_pie_1, _ = ax.pie(group_size_1, radius=radius-0*size, #labels=group_names_1, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[blues(0.8), reds(0.8)])

nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[reds(0.2), reds(0.4)])


    
plt.margins(0,0)
#plt.show()

# %%
group_names_1 = ['Structure', 'Sequence']
group_size_1 = [5976, 51830]

group_names_2 = ['Structures with at least one paired VH/VL', '', '', 'Antibodies, against different targets', '']
group_size_2 = [5025-1924, 1924, 251, 700, 51830]



fig, ax = plt.subplots(dpi=400)
#ax = ax.flatten(dpi=400)
ax.axis('equal')


radius = 3
size = 0.3

blues, reds, greens = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]
ab20b, tab20c = [plt.cm.tab20b, plt.cm.tab20c]

nested_pie_1, _ = ax.pie(group_size_1, radius=radius-0*size, #labels=group_names_1, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[blues(0.8), 'w'])

nested_pie_2, _ = ax.pie(group_size_2, radius=radius-1*size,# labels=group_names_2, 
                         wedgeprops=dict(width=size, edgecolor='w'), startangle=90,
                         colors=[blues(0.1), blues(0.3), blues(0.5), blues(0.7), 'w'])


    
plt.margins(0,0)
#plt.show()
